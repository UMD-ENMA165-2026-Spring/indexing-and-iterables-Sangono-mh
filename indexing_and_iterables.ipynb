# %% [markdown]
# ##### **Content under Creative Commons Attribution license [CC-BY 4.0](LICENSE/CC-BY-4.0.md); Code licensed under [BSD 3-Clause Clear](LICENSE/BSD3CLAUSE.md) © 2025 by J. E. Guyer**
#
# **Student submissions licensed under [UMD Academic License](LICENSE/UMDACADEMIC.md) © 2025 by YOUR NAME HERE**

# %% [markdown]
# # ENMA165: Indexing, Slicing, and Iterables (100 points total)
#
# Submit your solutions in the cells of this notebook as a **pull request**.
#
# Answers will be scored on correctness, conciseness, and descriptive variable names. Comments which help clarify the code are encouraged; comments which are redundant to the code are not.
#
# While some questions can be answered by casual observation of the data, your assignment is to *write code* that produces the answers.
#
# Use tab-completion, `help()`, and other forms of Python introspection to identify the functions and methods you need, what arguments they take, and what values they return.

# %% [markdown]
# ## Q1 (4 points)
#
# Print character 0 from the string `"helium"`

# %%
print("helium"[0])

# %% [markdown]
# ## Q2 (4 points)
#
# Print character 3 from the string `"helium"`

# %%
print("helium"[3])

# %% [markdown]
# ## Q3 (4 points)
#
# Print the last character from the string `"helium"`

# %%
print("helium"[-1])

# %% [markdown]
# ## Q4 (4 points)
#
# Given
# ```python
# s = "helium"
# ```
# which of the following will print "`liu`"?
#
# 1. `print(s[2:4])`
# 1. `print(s[2:5])`
# 1. `print(s[-5:-2])`
# 1. `print(s[-2:-5])`
# 1. `print(s[-4:-1])`

# %% [markdown]
# 2. print(s[2:5])
# 5. print(s[-4:-1])

# %% [markdown]
# For the options that don't print "`liu`", explain why not:

# %% [markdown]
# When printing a string with an index like this, it starts at the first index and stops at the one right before the end index. So the first option omits the "u". If indexing backwards, it counts backwards, keeping the first index as 0 and starting at the end for -1, it will continue, and for -5 to -2 it gives us eli. Option 4 won't print anything because it can't count forward from -2 to get to -5.

# %% [markdown]
# ## Q5 (4 points)
#
# Given
# ```python
# s = "supercalifragilisticexpialidocious"
# ```
# which of the following will print "`i`"?
#
# 1. `print(s[8])`
# 2. `print(s[8.0])`
# 3. `print(s[-8])`
# 4. `print(s[13:13])`
# 5. `print(s[13:14])`
# 6. `print(s[14:17][-2])`
# 7. `print([s[16], s[18], s[20]][1])`
# 5. `print(s[::-1][4])`

# %% [markdown]
# 1. print(s[8])
# 3. print(s[-8])
# 5. print(s[13:14])
# 6. print(s[14:17][-2])
# 7. print([s[16], s[18], s[20]][1])

# %% [markdown]
# For the options that don't print "`i`", explain why not:

# %% [markdown]
# For option 2 we can't use floats. For option 4 it starts at index 13 and ends there so there is not output. For option 8 it reverses the string since we omitted the start and end so it jsut uses the whole string and with a step size of -1 it will use the reverse of the string and if we count backwards setting the last letter in the normal index to 0 we get it to print 0.

# %% [markdown]
# ## Q6 (4 points)
#
# Print every other character from the string `"supercalifragilisticexpialidocious"`, starting from the first "s"

# %%
s = "supercalifragilisticexpialidocious"
print(s[::2])
# Out:
# sprairglsiepaioiu

# %% [markdown]
# ## Q7 (4 points)
#
# Print every other character from the string `"supercalifragilisticexpialidocious"`, starting from the first "u"

# %%
s = "supercalifragilisticexpialidocious"
print(s[1::2])
# Out:
# ueclfaiitcxildcos

# %% [markdown]
# ## Q8 (4 points)
#
# Without executing the code, what do you think is the result of
# ```python
# s = "supercalifragilisticexpialidocious"
# print(s[0:5])
# ```

# %% [markdown]
# It will print "super".

# %% [markdown]
# What is the actual result of executing the code?

# %%
s = "supercalifragilisticexpialidocious"
print(s[0:5])
# Out:
# super

# %% [markdown]
# ## Q9 (4 points)
#
# Without executing the code, what\do you think is the result of
# ```python
# s = "supercalifragilisticexpialidocious"
# print(s[5:10])
# ```

# %% [markdown]
# It will print "calif".

# %% [markdown]
# What is the actual result of executing the code?

# %%
s = "supercalifragilisticexpialidocious"
print(s[5:10])
# Out:
# calif

# %% [markdown]
# ## Q10 (4 points)
#
# Without executing the code, what do you think is the result of
# ```python
# s = "supercalifragilisticexpialidocious"
# print(s[-10:-5])
# ```

# %% [markdown]
# It will print "alido".

# %% [markdown]
# What is the actual result of executing the code?

# %%
s = "supercalifragilisticexpialidocious"
print(s[-10:-5])
# Out:
# alido

# %% [markdown]
# ## Q11 (4 points)
#
# Without executing the code, what do you think is the result of
# ```python
# s = "supercalifragilisticexpialidocious"
# print(s[-5:-10])
# ```

# %% [markdown]
# It will print nothing.

# %% [markdown]
# What is the actual result of executing the code?

# %%
s = "supercalifragilisticexpialidocious"
print(s[-5:-10])

# %% [markdown]
# ## Q12 (4 points)
#
# Without executing the code, what do you think is the result of
# ```python
# s = "supercalifragilisticexpialidocious"
# print(s[-5:-10:-1])
# ```

# %% [markdown]
# It will print "odila".

# %% [markdown]
# What is the actual result of executing the code?

# %%
s = "supercalifragilisticexpialidocious"
print(s[-5:-10:-1])
# Out:
# codil

# %% [markdown]
# ## Q13 (4 points)
#
# Print item three in the list `["apple", "banana", "canteloupe", "durian"]`

# %%
fruit = ["apple", "banana", "cantaloupe", "durian"]
print(fruit[0:3:1])
# Out:
# ['apple', 'banana', 'cantaloupe']

# %% [markdown]
# ## Q14 (4 points)
#
# Print the last item in the list `["apple", "banana", "canteloupe", "durian"]`

# %%
fruit = ["apple", "banana", "cantaloupe", "durian"]
print(fruit[3])
# Out:
# durian

# %% [markdown]
# ## Q15 (4 points)
#
# Fill in the blanks to produce the output
# ```
# a
# b
# c
# d
# ```

# %%
for i in ["apple", "banana", "canteloupe", "durian"]:
    print(i)
# Out:
# apple
# banana
# canteloupe
# durian

# %% [markdown]
# ## Q16 (4 points)
#
# Print character 3 of item 3 in the list `["apple", "banana", "canteloupe", "durian"]`

# %%
fruit = ["apple", "banana", "cantaloupe", "durian"]
print(fruit[2][2])
# Out:
# n

# %% [markdown]
# ## Q17 (4 points)
#
# Without executing the code, what do you think is the result of
# ```python
# l = ["apple", "banana", "canteloupe", "durian"]
# del l[-2]
# print(l[2])
# ```

# %% [markdown]
# It will print "durian".

# %% [markdown]
# What is the actual result of executing the code?

# %%
l = ["apple", "banana", "canteloupe", "durian"]
del l[-2]
print(l[2])
# Out:
# durian

# %% [markdown]
# ## Q18 (4 points)
#
# Given
# ```python
# d = {"apple": 1.414, "banana": 1.618, "canteloupe": 2.718, "durian": 3.142}
# ```
# Which of the following will print "`1.618`"?
#
# 1. `print(d["apple"])`
# 1. `print(d["banana"])`
# 1. `print(d[1])`
# 1. `print(d[banana])`

# %% [markdown]
# 2. print(d[["banana"])

# %% [markdown]
# For the options that don't print "`1.618`", explain why not:

# %% [markdown]
# Option 1 will print 1.414. Option 3 is invalid because a dictionary doesn't work like an index. Option 4 is invalid because it needs to be a string input.

# %% [markdown]
# ## Q19 (4 points)
#
# Given
# ```python
# d = {"apple": 2, "banana": "2", "canteloupe": 2.0, "durian": "2.0", 2: 2}
# ```
# which of the following will print "`2`"?
#
# 1. `print(d["apple"])`
# 1. `print(d["banana"])`
# 1. `print(d["canteloupe"])`
# 1. `print(d["durian"])`
# 1. `print(d[0])`
# 1. `print(d[2])`
# 1. `print(str(d["canteloupe"])[0])`
# 1. `print(int(d["durian"]))`

# %% [markdown]
# 1. print(d["apple"])
# 2. print(d["banana"])
# 7. print(str(d["canteloupe"])[0])

# %% [markdown]
# For the options that don't print "`2`", explain why not:

# %% [markdown]
# Option 3 prints 2.0. Option 4 prints "2.0". Option 5 and 6 are unexecutable because the arguments are wrong. Option 8 needs to turn the string into a flaot before it can become an integer.

# %% [markdown]
# ## Q20 (4 points)
#
# Given
# ```python
# d = {"apple": [1.414, 1.618], "banana": [1.618, 1.414], "canteloupe": [2.718, 3.142], "durian": 1.618}
# ```
# which of the following will print "`1.618`"?
#
# 1. `print(d["apple", 1])`
# 1. `print(d["apple"][1])`
# 1. `print(d["banana"])`
# 1. `print(d["banana"][0])`
# 1. `print(d["banana"][1])`
# 1. `print(d["canteloupe"][0])`
# 1. `print(d["durian"])`
# 1. `print(d["durian"][0])`

# %% [markdown]
# 2. print (d["apple"][1])
# 4. print (d["banana"][0])
# 7. print (d["durian"])

# %% [markdown]
# For the options that don't print "`1.618`", explain why not:

# %% [markdown]
# Option 1 it would attempt to print the values of "apple" and 1 but no 1 exists in the disctionary so it fails. Option 3 would print the whole index for "banana". Option 5 would print 1.414. Option 6 would print 2.718. Option 8 would not work because durian is not an index.

# %% [markdown]
# ## Q21 (4 points)
#
# Using the `enumerate()` command, fill in the blanks in the next cell to produce the output:
# ```
# 0: apple
# 1: banana
# 2: canteloupe
# 3: durian
# ```

# %%
a = ["apple", "banana", "canteloupe", "durian"]

for i, item in enumerate(a):
    print(f"{i}: {item}")
# Out:
# 0: apple
# 1: banana
# 2: canteloupe
# 3: durian

# %% [markdown]
# ## Q22 (4 pts)
#
# Fill in the blanks in the next cell to produce the ouput:
# ```
# The value of apple is 1.414
# The value of banana is 1.618
# The value of canteloupe is 2.718
# The value of durian is 3.142
# ```
#
# **note:** The lines may be in a different order

# %%
d = {"apple": 1.414, "banana": 1.618, "canteloupe": 2.718, "durian": 3.142}

for fruit, i in d.items():
    print("The value of ", fruit, " is ", i, "." )
# Out:
# The value of  apple  is  1.414 .
# The value of  banana  is  1.618 .
# The value of  canteloupe  is  2.718 .
# The value of  durian  is  3.142 .

# %% [markdown]
# ## Q23 (4 pts)
#
# Using the `zip()` command, fill in the blanks in the next cell to produce the ouput:
# ```
# fruit: apple, number: 1.414, valid: True
# fruit: banana, number: 1.618, valid: False
# fruit: canteloupe, number: 2.718, valid: False
# fruit: durian, number: 3.142, valid: True
# ```

# %%
a = ["apple", "banana", "canteloupe", "durian"]
b = [1.414, 1.618, 2.718, 3.142]
c = [True, False, False, True]
#redo
for a,b,c in zip(a,b,c):
    print(f"fruit: {a}, number: {b}, valid: {c}")
# Out:
# fruit: apple, number: 1.414, valid: True
# fruit: banana, number: 1.618, valid: False
# fruit: canteloupe, number: 2.718, valid: False
# fruit: durian, number: 3.142, valid: True

# %% [markdown]
# ## Q24 (4 pts)
#
# Fill in the blanks in the next cell to produce the ouput:
# ```
# 0: The value of apple is 1.414
# 1: The value of banana is 1.618
# 2: The value of canteloupe is 2.718
# 3: The value of durian is 3.142
# ```

# %%
d = {"fruit": ["apple", "banana", "canteloupe", "durian"],
     "transcendental number": [1.414, 1.618, 2.718, 3.142],
     "valid": [True, False, False, True]}

for i, (j, k) in enumerate(zip(d["fruit"],d["transcendental number"])):
    print(f"{i}: The value of {j} is {k}")
# Out:
# 0: The value of apple is 1.414
# 1: The value of banana is 1.618
# 2: The value of canteloupe is 2.718
# 3: The value of durian is 3.142

# %% [markdown]
# ## Q25 (4 pts)
#
# Fill in the blanks in the next cell to produce the ouput:
# ```
# 0: The value of apple is 1.414
# 3: The value of durian is 3.142
# ```

# %%
d = {"fruit": ["apple", "banana", "canteloupe", "durian"],
     "transcendental number": [1.414, 1.618, 2.718, 3.142],
     "valid": [True, False, False, True]}

for i, (j, k, l) in enumerate(zip(d["fruit"],d["transcendental number"],d["valid"])):
    if l:
        print(f"{i}: The value of {j} is {k}")
# Out:
# 0: The value of apple is 1.414
# 3: The value of durian is 3.142
